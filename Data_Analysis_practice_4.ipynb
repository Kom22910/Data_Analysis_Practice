# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error , r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/YBI-Foundation/Dataset/main/Air%20Quality%20Missing%20Data.csv")

# %%
df
# Out:
#            Date  Ozone  Solar  Wind  Temp
# 0    01-05-1976   41.0  190.0   7.4    67
# 1    02-05-1976   36.0  118.0   8.0    72
# 2    03-05-1976   12.0  149.0  12.6    74
# 3    04-05-1976   18.0  313.0  11.5    62
# 4    05-05-1976    NaN    NaN  14.3    56
# ..          ...    ...    ...   ...   ...
# 148  26-09-1976   30.0  193.0   6.9    70
# 149  27-09-1976    NaN  145.0  13.2    77
# 150  28-09-1976   14.0  191.0  14.3    75
# 151  29-09-1976   18.0  131.0   8.0    76
# 152  30-09-1976   20.0  223.0  11.5    68
#
# [153 rows x 5 columns]

# %%
df.describe()
# Out:
#             Ozone       Solar        Wind        Temp
# count  116.000000  146.000000  153.000000  153.000000
# mean    42.129310  185.931507    9.957516   77.882353
# std     32.987885   90.058422    3.523001    9.465270
# min      1.000000    7.000000    1.700000   56.000000
# 25%     18.000000  115.750000    7.400000   72.000000
# 50%     31.500000  205.000000    9.700000   79.000000
# 75%     63.250000  258.750000   11.500000   85.000000
# max    168.000000  334.000000   20.700000   97.000000

# %% [markdown]
# # Q1 How many rows and columns are there in the dataset?

# %%
df.shape
# Out:
# (153, 5)

# %% [markdown]
# # Q2 What are the column names and their data types?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    153 non-null    object
#  1   Ozone   116 non-null    float64
#  2   Solar   146 non-null    float64
#  3   Wind    153 non-null    float64
#  4   Temp    153 non-null    int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 6.1+ KB

# %% [markdown]
# # Q3 What are the names of the columns in the dataset, and what do they represent?

# %%
df.head()
# Out:
#          Date  Ozone       Solar  Wind  Temp
# 0  01-05-1976   41.0  190.000000   7.4    67
# 1  02-05-1976   36.0  118.000000   8.0    72
# 2  03-05-1976   12.0  149.000000  12.6    74
# 3  04-05-1976   18.0  313.000000  11.5    62
# 4  05-05-1976   23.0  308.333333  14.3    56

# %% [markdown]
# *   **Date**   =======> date of observation
# *  **Ozone**	 =======> o3 count
# *   **Solar**  =======> solar count
# *   **Wind**  =======> wind count
# *  **Temp**   =======> temperature observe

# %% [markdown]
# # Q4 Are there any missing values in the dataset?

# %%
df.isnull().sum()
# Out:
# Date      0
# Ozone    37
# Solar     7
# Wind      0
# Temp      0
# dtype: int64

# %% [markdown]
# **yes there are missing value**

# %% [markdown]
# # Q5 If there are missing values, how are they represented?

# %% [markdown]
# *   **NaN (Not a Number)**:   In many datasets, missing values are represented using the NaN value, which stands for "Not a Number." In Pandas, missing numerical values are typically represented as NaN.
#
# *   **Null or Empty Values**:  Some datasets may represent missing values as null or empty strings in string columns.
#
# *  **Placeholder Values**: In some cases, missing values are represented using specific placeholder values that are distinct from valid data. For example, a negative number, a zero, or a specific string could be used as a placeholder for missing data.
#
# *   **Special Codes**: In certain datasets, special codes or symbols might be used to denote missing values. These codes are not valid data entries but serve as placeholders

# %%
df.isnull()
# Out:
#       Date  Ozone  Solar   Wind   Temp
# 0    False  False  False  False  False
# 1    False  False  False  False  False
# 2    False  False  False  False  False
# 3    False  False  False  False  False
# 4    False   True   True  False  False
# ..     ...    ...    ...    ...    ...
# 148  False  False  False  False  False
# 149  False   True  False  False  False
# 150  False  False  False  False  False
# 151  False  False  False  False  False
# 152  False  False  False  False  False
#
# [153 rows x 5 columns]

# %%
df
# Out:
#            Date  Ozone  Solar  Wind  Temp
# 0    01-05-1976   41.0  190.0   7.4    67
# 1    02-05-1976   36.0  118.0   8.0    72
# 2    03-05-1976   12.0  149.0  12.6    74
# 3    04-05-1976   18.0  313.0  11.5    62
# 4    05-05-1976    NaN    NaN  14.3    56
# ..          ...    ...    ...   ...   ...
# 148  26-09-1976   30.0  193.0   6.9    70
# 149  27-09-1976    NaN  145.0  13.2    77
# 150  28-09-1976   14.0  191.0  14.3    75
# 151  29-09-1976   18.0  131.0   8.0    76
# 152  30-09-1976   20.0  223.0  11.5    68
#
# [153 rows x 5 columns]

# %% [markdown]
# **Missing value are represented by Nan**

# %% [markdown]
# # Q6 What methods or strategies would you use to handle missing data in this dataset?

# %% [markdown]
# **using fillna method**e with interpolation

# %%
df.isnull().sum()
# Out:
# Date      0
# Ozone    37
# Solar     7
# Wind      0
# Temp      0
# dtype: int64

# %%
df["Ozone"].interpolate(method = "linear" , inplace = True)
df["Solar"].interpolate(method = "linear" , inplace = True)

# %%
df.isnull().sum()
# Out:
# Date     0
# Ozone    0
# Solar    0
# Wind     0
# Temp     0
# dtype: int64

# %% [markdown]
# # Q7 Are there any duplicated rows in the dataset? How would you deal with them if present?

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Q8 What are some common visualizations you can create to better understand the data, such as histograms, scatter plots, or box plots?

# %%
df.columns
# Out:
# Index(['Date', 'Ozone', 'Solar', 'Wind', 'Temp'], dtype='object')

# %%
px.histogram(df , x = "Ozone" , y = "Solar")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="808f22de-80af-44b5-827e-b60b8d743e7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("808f22de-80af-44b5-827e-b60b8d743e7a")) {                    Plotly.newPlot(                        "808f22de-80af-44b5-827e-b60b8d743e7a",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"Ozone=%{x}\u003cbr\u003esum of Solar=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[41.0,36.0,12.0,18.0,23.0,28.0,23.0,19.0,8.0,7.5,7.0,16.0,11.0,14.0,18.0,14.0,34.0,6.0,30.0,11.0,1.0,11.0,4.0,32.0,29.75,27.5,25.25,23.0,45.0,115.0,37.0,35.857142857142854,34.714285714285715,33.57142857142857,32.42857142857143,31.285714285714285,30.142857142857142,29.0,50.0,71.0,39.0,33.666666666666664,28.333333333333336,23.0,22.333333333333332,21.666666666666668,21.0,37.0,20.0,12.0,13.0,24.090909090909093,35.18181818181819,46.27272727272727,57.36363636363637,68.45454545454547,79.54545454545455,90.63636363636364,101.72727272727273,112.81818181818183,123.90909090909092,135.0,49.0,32.0,48.0,64.0,40.0,77.0,97.0,97.0,85.0,47.5,10.0,27.0,17.0,7.0,48.0,35.0,61.0,79.0,63.0,16.0,37.33333333333333,58.666666666666664,80.0,108.0,20.0,52.0,82.0,50.0,64.0,59.0,39.0,9.0,16.0,78.0,35.0,66.0,122.0,89.0,110.0,88.0,66.0,44.0,28.0,65.0,43.5,22.0,59.0,23.0,31.0,44.0,21.0,
:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#           Ozone     Solar      Wind      Temp
# Ozone  1.000000  0.159473 -0.507534  0.601636
# Solar  0.159473  1.000000 -0.029280  0.229697
# Wind  -0.507534 -0.029280  1.000000 -0.457988
# Temp   0.601636  0.229697 -0.457988  1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Ozone'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_1, *['Solar'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_2, *['Wind'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_3, *['Temp'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_4, *['Ozone'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_5, *['Solar'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_6, *['Wind'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_7, *['Temp'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(_df_8, *[[['Ozone', 'Solar'], ['Solar', 'Wind'], ['Wind', 'Temp']]], **{})
# chart

# %% [markdown]
# # Q13 Is there is data time-stamped? If so, what is the time range covered by the dataset?

# %%
df["Date"]                         #  there is no time
# Out:
# 0      01-05-1976
# 1      02-05-1976
# 2      03-05-1976
# 3      04-05-1976
# 4      05-05-1976
#           ...
# 148    26-09-1976
# 149    27-09-1976
# 150    28-09-1976
# 151    29-09-1976
# 152    30-09-1976
# Name: Date, Length: 153, dtype: object

# %% [markdown]
# # Q14 How would you resample or aggregate the data to analyze it on a daily or monthly basis?

# %%
df.resample("M").mean()     # Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-fcd9b5bc1b2d> in <cell line: 1>()
# ----> 1 df.resample("M").mean()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#   11390         group_keys: bool | lib.NoDefault = no_default,
#   11391     ) -> Resampler:
# > 11392         return super().resample(
#   11393             rule=rule,
#   11394             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset, group_keys)
#    8856
#    8857         axis = self._get_axis_number(axis)
# -> 8858         return get_resampler(
#    8859             self,
#    8860             freq=rule,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in get_resampler(obj, kind, **kwds)
#    1542     """
#    1543     tg = TimeGrouper(**kwds)
# -> 1544     return tg._get_resampler(obj, kind=kind)
#    1545
#    1546
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    1723             )
#    1724
# -> 1725         raise TypeError(
#    1726             "Only valid with DatetimeIndex, "
#    1727             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %% [markdown]
# # Q15 Does the dataset include location information (latitude and longitude)?

# %%
df.head()
# Out:
#          Date  Ozone       Solar  Wind  Temp
# 0  01-05-1976   41.0  190.000000   7.4    67
# 1  02-05-1976   36.0  118.000000   8.0    72
# 2  03-05-1976   12.0  149.000000  12.6    74
# 3  04-05-1976   18.0  313.000000  11.5    62
# 4  05-05-1976   23.0  308.333333  14.3    56

# %% [markdown]
# **there is no location info**

# %% [markdown]
# # Q16 Can you apply a regression model to predict air quality measurements  based on other variables in the dataset?

# %%
df.columns
# Out:
# Index(['Date', 'Ozone', 'Solar', 'Wind', 'Temp'], dtype='object')

# %%
target = "Wind"
features = ["Date","Ozone" , "Solar","Temp"]

# %%
#  Split the data into training and testing sets

x = df[features].values
y = df[target].values

x_train , x_test , y_train , y_test = train_test_split(x, y ,test_size = 0.2 , random_state=42)

# %%
lr = LinearRegression()
y_pred = lr.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
